# %%
# !nvidia-smi
# Out:
# Wed Apr  3 06:39:20 2024
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.14              Driver Version: 550.54.14      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A10G                    On  |   00000000:00:1B.0 Off |                    0 |
# |  0%   28C    P0             66W /  300W |   21510MiB /  23028MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   1  NVIDIA A10G                    On  |   00000000:00:1C.0 Off |                    0 |
# |  0%   29C    P0             82W /  300W |    1425MiB /  23028MiB |     25%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   2  NVIDIA A10G                    On  |   00000000:00:1D.0 Off |                    0 |
# |  0%   28C    P0             69W /  300W |    7698MiB /  23028MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
# |   3  NVIDIA A10G                    On  |   00000000:00:1E.0 Off |                    0 |
# |  0%   21C    P8             22W /  300W |       3MiB /  23028MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# +-----------------------------------------------------------------------------------------+

# %%
# base model from huggingFace or path to model
base_model = "mistralai/Mistral-7B-Instruct-v0.2"
# new_model = "Enlighten_Instruct"
new_model = "Enlighten_Instruct-alan-v1"


test_path='/opt/app-root/src/Enlighten-Instruct/Dataset/TestData.csv'
train_path='/opt/app-root/src/Enlighten-Instruct/Dataset/TrainData.csv'

# %%
# !git clone 'https://github.com/ali7919/Enlighten-Instruct.git'
# !pip install -U bitsandbytes --quiet
# !pip install transformers==4.36.2 --quiet
# !pip install -U peft --quiet
# !pip install -U accelerate --quiet
# !pip install -U trl --quiet
# !pip install datasets==2.16.0 --quiet
# !pip install sentencepiece --quiet
# Out:
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# codeflare-torchx 0.6.0.dev2 requires docstring-parser==0.8.1, but you have docstring-parser 0.16 which is incompatible.
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# codeflare-torchx 0.6.0.dev2 requires docstring-parser==0.8.1, but you have docstring-parser 0.16 which is incompatible.
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip available: 22.2.2 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig,HfArgumentParser,TrainingArguments,pipeline, logging
from peft import LoraConfig, PeftModel, prepare_model_for_kbit_training, get_peft_model
import os,torch
from datasets import load_dataset
from trl import SFTTrainer
import pandas as pd
import pyarrow as pa
import pyarrow.dataset as ds
import pandas as pd
from datasets import Dataset
import re

# %% [markdown]
# # Login to HF

# %%
from huggingface_hub import HfApi, HfFolder
token = "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"
HfFolder.save_token(token)

# %% [markdown]
# # Build Dataset

# %%
df = pd.read_csv(train_path)

# build training dataset with the right format
df['text'] = '<s>[INST]@Enlighten. ' + df['Q'] +'[/INST]'+ df['A'] + '</s>'

# remove columns
df=df.drop(['Q','A','class'],axis=1)

# convert to dataset object
dataset = ds.dataset(pa.Table.from_pandas(df).to_batches())
dataset = Dataset(pa.Table.from_pandas(df))
dataset
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 1910
# })

# %% [markdown]
# # Load the model

# %%
# Load base model
bnb_config = BitsAndBytesConfig(
    load_in_4bit= True,
    bnb_4bit_quant_type= "nf4",
    bnb_4bit_compute_dtype= torch.bfloat16,
    bnb_4bit_use_double_quant= False,
)
model = AutoModelForCausalLM.from_pretrained(
        base_model,
        load_in_4bit=True,
        quantization_config=bnb_config,
        torch_dtype=torch.bfloat16,
        device_map="auto",
        trust_remote_code=True,
)


model.config.use_cache = False # silence the warnings. Please re-enable for inference!
model.config.pretraining_tp = 1
model.gradient_checkpointing_enable()

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(base_model, trust_remote_code=True)
tokenizer.padding_side = 'right'
tokenizer.pad_token = tokenizer.eos_token
tokenizer.add_eos_token = True
tokenizer.bos_token, tokenizer.eos_token
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ('<s>', '</s>')

# %%
# count trainging tokens
from transformers import LlamaTokenizer
tokenizer_ = LlamaTokenizer.from_pretrained("cognitivecomputations/dolphin-llama2-7b")
tokens = tokenizer_.tokenize(dataset.to_pandas().to_string())
len(tokens)
# Out:
# 962734

# %% [markdown]
# # Fine-Tune

# %%
#Adding the adapters in the layers
model = prepare_model_for_kbit_training(model)
peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=64,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj","gate_proj"]
)
model = get_peft_model(model, peft_config)

# %%
#Hyperparamter
training_arguments = TrainingArguments(
    output_dir="./results",
    num_train_epochs=1,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=1,
    optim="paged_adamw_32bit",
    save_steps=50,
    logging_steps=1,
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=False,
    bf16=False,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="constant",
)

# %%
# Setting sft parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=peft_config,
    max_seq_length= None,
    dataset_text_field="text",
    tokenizer=tokenizer,
    args=training_arguments,
    packing= False,
)
# Out:
# /opt/app-root/lib64/python3.9/site-packages/trl/trainer/sft_trainer.py:245: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# Map:   0%|          | 0/1910 [00:00<?, ? examples/s]
# /opt/app-root/lib64/python3.9/site-packages/accelerate/accelerator.py:432: FutureWarning: Passing the following arguments to `Accelerator` is deprecated and will be removed in version 1.0 of Accelerate: dict_keys(['dispatch_batches', 'split_batches']). Please pass an `accelerate.DataLoaderConfiguration` instead:
# dataloader_config = DataLoaderConfiguration(dispatch_batches=None, split_batches=False)
#   warnings.warn(

# %%
trainer.train()
# Out:
# You're using a LlamaTokenizerFast tokenizer. Please note that with a fast tokenizer, using the `__call__` method is faster than using a method to encode the text followed by a call to the `pad` method to get a padded encoding.
#     <div>
#
#       <progress value='478' max='478' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [478/478 17:11, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.542700</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.716800</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.073800</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.758500</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.573700</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.408700</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.142700</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>1.989000</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>1.972400</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.807500</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>1.966200</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.663700</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.679700</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.485100</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>1.882700</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.172500</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.798900</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.808800</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.676000</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>1.901000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.776400</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.639100</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.638500</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.705300</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.881100</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.492700</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.520500</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.836800</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.440700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.646800</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.694100</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.624900</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.337000</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.810100</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.602200</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.575300</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.455200</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.507200</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.321600</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.511600</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.625500</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.474200</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.235300</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.726000</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.819100</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.444100</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.579400</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.419200</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.661100</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.770900</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>0.944800</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.248100</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1.429700</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.257700</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.419900</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.080700</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.129100</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1.305800</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>1.452700</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.151200</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>1.033100</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.947000</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>1.339800</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>0.980400</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>1.280900</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>1.189700</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>1.230800</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>1.161700</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.990500</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.208500</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>1.326400</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.159000</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.446600</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.148600</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.526600</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>1.128700</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>1.127700</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.968900</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>1.123900</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.025900</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>1.157800</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>1.254700</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1.044000</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.936900</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.242900</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>1.213700</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>1.037200</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.341600</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.877100</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.023300</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>0.972300</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.358000</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>1.127500</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.086700</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1.071600</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.900900</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.986600</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.016300</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>0.968700</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.279700</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.898900</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>1.009400</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.973100</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>1.284200</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.940700</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>1.049500</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>0.981300</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>1.170200</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>1.019200</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.065500</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>1.064100</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>1.027700</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>1.262300</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>1.131400</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.993700</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>1.054700</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.977200</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>1.158500</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.783300</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.149000</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>1.097400</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>1.212300</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.901000</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.904400</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.957200</td>
#     </tr>
#     <tr>
#       <td>126</t
# Checkpoint destination directory ./results/checkpoint-50 already exists and is non-empty.Saving will proceed but saved results may be invalid.
# Checkpoint destination directory ./results/checkpoint-100 already exists and is non-empty.Saving will proceed but saved results may be invalid.
# Checkpoint destination directory ./results/checkpoint-150 already exists and is non-empty.Saving will proceed but saved results may be invalid.
# Checkpoint destination directory ./results/checkpoint-200 already exists and is non-empty.Saving will proceed but saved results may be invalid.
# Checkpoint destination directory ./results/checkpoint-250 already exists and is non-empty.Saving will proceed but saved results may be invalid.
# Checkpoint destination directory ./results/checkpoint-300 already exists and is non-empty.Saving will proceed but saved results may be invalid.
# Checkpoint destination directory ./results/checkpoint-350 already exists and is non-empty.Saving will proceed but saved results may be invalid.
# Checkpoint destination directory ./results/checkpoint-400 already exists and is non-empty.Saving will proceed but saved results may be invalid.
# Checkpoint destination directory ./results/checkpoint-450 already exists and is non-empty.Saving will proceed but saved results may be invalid.
# TrainOutput(global_step=478, training_loss=1.0010469777813515, metrics={'train_runtime': 1046.3867, 'train_samples_per_second': 1.825, 'train_steps_per_second': 0.457, 'total_flos': 8899283549110272.0, 'train_loss': 1.0010469777813515, 'epoch': 1.0})

# %% [markdown]
# # Save and push the adapter to HF

# %%
# Save the fine-tuned model
trainer.model.save_pretrained(new_model)
model.config.use_cache = True
model.eval()
# Out:
# PeftModelForCausalLM(
#   (base_model): LoraModel(
#     (model): MistralForCausalLM(
#       (model): MistralModel(
#         (embed_tokens): Embedding(32000, 4096)
#         (layers): ModuleList(
#           (0-31): 32 x MistralDecoderLayer(
#             (self_attn): MistralAttention(
#               (q_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (k_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (v_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=1024, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=1024, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (o_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=4096, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=4096, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (rotary_emb): MistralRotaryEmbedding()
#             )
#             (mlp): MistralMLP(
#               (gate_proj): lora.Linear4bit(
#                 (base_layer): Linear4bit(in_features=4096, out_features=14336, bias=False)
#                 (lora_dropout): ModuleDict(
#                   (default): Dropout(p=0.1, inplace=False)
#                 )
#                 (lora_A): ModuleDict(
#                   (default): Linear(in_features=4096, out_features=64, bias=False)
#                 )
#                 (lora_B): ModuleDict(
#                   (default): Linear(in_features=64, out_features=14336, bias=False)
#                 )
#                 (lora_embedding_A): ParameterDict()
#                 (lora_embedding_B): ParameterDict()
#               )
#               (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#               (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#               (act_fn): SiLU()
#             )
#             (input_layernorm): MistralRMSNorm()
#             (post_attention_layernorm): MistralRMSNorm()
#           )
#         )
#         (norm): MistralRMSNorm()
#       )
#       (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
#     )
#   )
# )

# %%
trainer.model.push_to_hub(new_model)
# Out:
# adapter_model.safetensors:   0%|          | 0.00/369M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Liu-Xiang/Enlighten_Instruct-alan-v1/commit/9586f815cd96692632f206192d2367a9a1220d97', commit_message='Upload model', commit_description='', oid='9586f815cd96692632f206192d2367a9a1220d97', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# # Test the model

# %%
logging.set_verbosity(logging.CRITICAL)
pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=200)

# %%
def build_prompt(question):
  prompt=f"<s>[INST]@Enlighten. {question} [/INST]"
  return prompt

# %%
question = "what is the pwoer outage event?"
prompt = build_prompt(question)
result = pipe(prompt)

print(result[0]['generated_text'])
# Out:
# <s>[INST]@Enlighten. what is the pwoer outage event? [/INST] ```csharp
# public static event Action PowerOutage;
# ```
#
# it is called when the power is out.
#
# ```csharp
# PowerOutage?.Invoke();
# ```
#
# it is called when the power is back on.
#
# ```csharp
# PowerBackOn?.Invoke();
# ```
#
# it is called when the power is restored.
#
# ```csharp
# PowerRestored?.Invoke();
# ```
#
# it is called when the power is turned on.
#
# ```csharp
# PowerTurnedOn?.Invoke();
# ```
#
# it is called when the power is turned off.
#
# ```csharp
# PowerTurnedOff?.Invoke();
# ```
#
# it is called when the power is updated

# %%
df_test=pd.read_csv(test_path)

questionCounter=0
correct=0
promptEnding = "[/INST]"

# this must be >= 2
fail_limit=10

# chain of thought activator, model might run out of output tokens
USE_COT=True

#this comes before the question
testGuide='Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d \n'

for index, row in df_test.iterrows():
    print("#############################")
    questionCounter = questionCounter + 1

    #chain of thought activator
    if USE_COT:
        chainOfThoughtActivator='\nfirst think step by step\n'
    else:
        chainOfThoughtActivator='\n'

    #build the prompt
    question=testGuide + row['Question'] + '\na)' + row['a'] + '\nb)' + row['b'] + '\nc)' + row['c'] + '\nd)' + row['d'] + chainOfThoughtActivator
    print(question)

    #true answer
    truth=row['Answer']

    #use a loop, if llm stopped before reaching the answer. ask again
    index=-1
    failCounter=0
    while(index==-1):

        #build the prompt
        prompt = build_prompt(question)

        #generate answer
        result = pipe(prompt)
        llmAnswer = result[0]['generated_text']

        #remove our prompt from it
        index = llmAnswer.find(promptEnding)
        llmAnswer = llmAnswer[len(promptEnding)+index:]

        print("LLM Answer:")
        print(llmAnswer)

        #remove spaces
        llmAnswer=llmAnswer.replace(' ','')

        #find the option in response
        index = llmAnswer.find('Answer:')

        #edge case - llm stoped at the worst time
        if(index+len('Answer:')==len(llmAnswer)):
            index=-1

        #update question for the next try. remove chain of thought
        question=testGuide + row['Question'] + '\na)' + row['a'] + '\nb)' + row['b'] + '\nc)' + row['c'] + '\nd)' + row['d']

        #Don't get stock on a question
        failCounter=failCounter+1
        if failCounter==fail_limit:
            break

    if failCounter==fail_limit:
        continue

    #find and match the option
    next_char = llmAnswer[index+len('Answer:'):][0]
    if next_char in truth:
        correct=correct+1
        print('correct')
    else:
        print('wrong')

    #update accuracy
    accuracy=correct/questionCounter
    print(f"Progress: {questionCounter/len(df_test)}")
    print(f"Accuracy: {accuracy}")
# Out:
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the BeastAttack class do in the Unity project?
# a)Manages player movement
# b)Generates sounds
# c)Manages the beast attack behavior and player hit behavior
# d)Controls the camera
# first think step by step
#
# LLM Answer:
# c)Manages the beast attack behavior and player hit behavior
#
# Answer:c
# correct
# Progress: 0.0037174721189591076
# Accuracy: 1.0
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the gameObject that uses the BeastAttack.cs script need to have on it?
# a)A Rigidbody
# b)A Collider
# c)A Cinemachine Impulse Source
# d)All of the above
# first think step by step
#
# LLM Answer:
#  ```csharp
# //beast attack is a state, so the beast must have a collider to detect when it hits something
# //beast attack is a state, so the beast must have a rigidbody to move around
# //beast attack is a state, so the beast must have a cinemachine impulse source to shake the camera when it attacks
# //beast attack is a state, so the beast must have all of the above
#
# LLM Answer:
# Answer:b
#
# Explanation:
# The gameObject that uses the BeastAttack.cs script needs to have a Collider component attached to it. This is because the beast needs to be able to detect when it collides with the player.
#
# Therefore, the answer is:
# Answer:b
#
# Note:
# The gameObject that uses the BeastAttack.cs script may also have other components attached to it, such as a Rigid
# wrong
# Progress: 0.007434944237918215
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when the player gets hit while in the beast's Escaping state?
# a)The player is pushed back
# b)The player is pushed back and the beast enters a cooldown state
# c)The player is pushed back and the beast dies
# d)The player is not affected
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (hit.collider.CompareTag("Player")) {
#   playerManager.PushBack(impact);
#   if (navMeshAgent.remainingDistance > distanceToBeast) navMeshAgent.speed = normalSpeed;
#   else navMeshAgent.speed = 0;
#   if (navMeshAgent.speed == 0) navMeshAgent.
# LLM Answer:
# a)The player is pushed back
#
# Answer:a
# wrong
# Progress: 0.011152416356877323
# Accuracy: 0.3333333333333333
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the BeastKillsPlayerSequenceAnimator class?
# a)To control player movement
# b)To manage the beast killing player animation sequence
# c)To handle player combat actions
# d)To store references to key player components
# first think step by step
#
# LLM Answer:
# b)To manage the beast killing player animation sequence
#
# Answer:b
# correct
# Progress: 0.01486988847583643
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In the BeastKillsPlayerSequenceAnimator class, what does the StartSequence method do?
# a)Finds the farthest destination from the player
# b)Activates and plays the animation sequence
# c)Returns a random destination
# d)Sets the player position
# first think step by step
#
# LLM Answer:
#  ```csharp
# Activates and plays the animation sequence
# ```
# Answer: b.
# correct
# Progress: 0.01858736059479554
# Accuracy: 0.6
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the OnRespawnClicked method do in the BeastKillsPlayerSequenceAnimator class?
# a)Deactivates the animation sequence
# b)Teleports the player
# c)Sets the player position
# d)Finds the farthest destination from the player
# first think step by step
#
# LLM Answer:
#  ```csharp
# Deactivates the animation sequence
# ```
# Answer:a
# correct
# Progress: 0.022304832713754646
# Accuracy: 0.6666666666666666
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What states can the beast be in, according to the State enum?
# a)Sleep, On Target, Roaming, Escaping, and Bleeding
# b)Sleep, On Target, Roaming, Escaping, and Killing
# c)Sleep, On Target, Roaming, Escaping, and Attacking
# d)Sleep, On Target, Roaming, Escaping, and Stunned
# first think step by step
#
# LLM Answer:
#  ```csharp
# public enum State {
#     Sleep,
#     OnTarget,
#     Roaming,
#     Escaping,
#     Killing,
#     Bleeding,
#     Stunned
# }
# ```
#
# Answer: a
#
# The beast
# wrong
# Progress: 0.026022304832713755
# Accuracy: 0.5714285714285714
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when the lights are back on? (event LevelEventHub.OnLightsBackOn)
# a)The beast changes to state Sleep.
# b)The beast changes to state Killing.
# c)The beast changes to state Escaping.
# d)The beast changes to state Roaming.
# first think step by step
# /opt/app-root/lib64/python3.9/site-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# LLM Answer:
#  ```csharp
# if (beastState == BeastManager.State.Roaming) {
#   beastTransform.gameObject.SetActive(false);
# }
# ```
#
# ```csharp
# if (beastState == BeastManager.State.Roaming) {
#   beastTransform.gameObject.SetActive(true);
# }
# ```
# LLM Answer:
# a)The beast changes to state Sleep.
#
# Answer: a.
# wrong
# Progress: 0.02973977695167286
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the _scapingState variable?
# a)To control the beast's movement when it is escaping.
# b)To control the beast's movement when it is sleeping.
# c)To control the beast's movement when it is roaming.
# d)To control the beast's movement when it is on target.
# first think step by step
#
# LLM Answer:
#  ```csharp
# //set the state of the beast
# changeState(BeastManager.State.Roaming);
# ```
#
# ```csharp
# //set the state of the beast
# changeState(BeastManager.State.Roaming);
# ```
#
# ```csharp
# //set
# LLM Answer:
# a)To control the beast's movement when it is escaping.
# LLM Answer:
# a)To control the beast's movement when it is escaping.
# LLM Answer:
# a)To control the beast's movement when it is escaping.
# LLM Answer:
# a)To control the beast's movement when it is escaping.
# LLM Answer:
# a)To control the beast's movement when it is escaping.
# LLM Answer:
# a)To control the beast's movement when it is escaping.
# LLM Answer:
# a)To control the beast's movement when it is escaping.
# LLM Answer:
# a)To control the beast's movement when it is escaping.
# LLM Answer:
# a)To control the beast's movement when it is escaping.
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the BeastState abstract class in Unity's Beast.States namespace?
# a)To control player movement
# b)To manage some player behavior functionality
# c)To handle player combat actions
# d)To store references to key player components
# first think step by step
#
# LLM Answer:
#  ```csharp
# b)To manage some player behavior functionality
# ```
# Answer:b. The BeastState abstract class is responsible for managing some player behavior functionality.
# wrong
# Progress: 0.03717472118959108
# Accuracy: 0.4
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In the BeastState class, what is the purpose of the LookAt() method?
# a)To shoot a laser beam in a direction
# b)To slowly turn the head to face a target position
# c)To change the rotation of the entire beast to point it at a position
# d)To fire a projectile at a target
# first think step by step
#
# LLM Answer:
#  ```csharp
# b)To slowly turn the head to face a target position
# ```
# Answer: b.
# The LookAt() method is used to slowly turn the head of the beast to face a target position.
# correct
# Progress: 0.040892193308550186
# Accuracy: 0.45454545454545453
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which method in the BeastState class is responsible for setting up the state's properties and injecting its required parameters?
# a)Init()
# b)Activate()
# c)EnterState()
# d)Start()
# first think step by step
#
# LLM Answer:
#  ```csharp
# c)EnterState()
# ```
# Answer:c
#
# The EnterState method is responsible for setting up the state's properties and injecting its required parameters. It is called when the state is activated.
# wrong
# Progress: 0.04460966542750929
# Accuracy: 0.4166666666666667
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In the BeastStateKilling class, what is the purpose of the _timeLeft field?
# a)To store the time since the player was killed
# b)To store the time left until the beast starts attacking
# c)To store the time left before the beast changes state
# d)To store the time left until the beast kills the player
# first think step by step
#
# LLM Answer:
#  ```csharp
# //store the time left before the beast changes state
# ```
#
# Answer:c
# correct
# Progress: 0.048327137546468404
# Accuracy: 0.46153846153846156
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the Update() method do in the BeastStateKilling class?
# a)Hides the beast from the player
# b)Makes the beast look at the player and transition to roaming state after a certain time
# c)Makes the beast attack the player
# d)Makes the beast chase the player
# first think step by step
#
# LLM Answer:
# c)Makes the beast attack the player
#
# Answer:c
# wrong
# Progress: 0.05204460966542751
# Accuracy: 0.42857142857142855
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when the BeastStateKilling state is activated?
# a)The beast becomes invisible
# b)The beast's movement speed is set to normal
# c)The beast's attack cooldown is reset
# d)The beast's navigation path is reset
# first think step by step
#
# LLM Answer:
#  ```csharp
# //set the navMesh destination to the player's head
# navMeshAgent.SetDestination(player.position.position + player.position.up * 0.5f);
# //reset the attack cooldown
# attackTimer = 0;
# ```
#
# Answer: b and c. The beast's movement speed is set to normal and the attack cooldown is
# wrong
# Progress: 0.055762081784386616
# Accuracy: 0.4
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the 'eyeSightDistance' field in BeastStateOnTarget.cs?
# a)It stops other beasts from getting in the player's way.
# b)It sets the player's fast speed.
# c)It defines how far the beast can see.
# d)It determines the player's normal speed.
# first think step by step
#
# LLM Answer:
#  ```csharp
# c)It defines how far the beast can see.
# ```
# Answer:c.
# correct
# Progress: 0.05947955390334572
# Accuracy: 0.4375
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What will happen if the player is not in the beast's line of sight in BeastStateOnTarget.cs?
# a)The beast will charge at the player.
# b)The beast will continue chasing the player.
# c)The beast will transition to RoamingOnSight state.
# d)The beast will transition to Roaming state.
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# ```csharp
# if (navMeshAgent.remainingDistance > distanceToPlayerThatBeastRuns) navMeshAgent.speed = Const
# LLM Answer:
#  ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# LLM Answer:
#  ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# LLM Answer:
#  ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# LLM Answer:
#  ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# LLM Answer:
#  ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# LLM Answer:
#  ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# LLM Answer:
#  ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# LLM Answer:
#  ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# LLM Answer:
#  ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# ```csharp
# if (!navMeshAgent.enabled) navMeshAgent.enabled = true;
# navMeshAgent.SetDestination(player.position);
# ```
#
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# When does the beast start running toward the player in BeastStateOnTarget.cs?
# a)When the player is within a certain distance.
# b)When the beast is on cooldown.
# c)When the beast is in RoamingOnSight state.
# d)When the player is not in the beast's line of sight.
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (navMeshAgent.remainingDistance > distanceToPlayer) navMeshAgent.speed = normalSpeed;
# else navMeshAgent.speed = fastSpeed;
# ```
#
# ```csharp
# if (navMeshAgent.remainingDistance > distanceToPlayer) navMeshAgent.speed = normal
# LLM Answer:
# a)When the player is within a certain distance.
# Answer:a
# correct
# Progress: 0.06691449814126393
# Accuracy: 0.4444444444444444
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateRoaming.cs, what is the purpose of the `CheckForPlayerInSight()` method?
# a)To check if the player is in the beast's line of sight.
# b)To check if the player is making sound.
# c)To update the beast's current roaming position.
# d)To change the beast's state to OnTarget.
# first think step by step
#
# LLM Answer:
#  ```csharp
# //check if the player is in the beast's line of sight
# if (CheckForPlayerInSight()) {
#   //change the state to OnTarget
#   changeState(BeastManager.State.OnTarget);
# }
# ```
#
# An
# LLM Answer:
# a)To check if the player is in the beast's line of sight.
# Answer:a
# correct
# Progress: 0.07063197026022305
# Accuracy: 0.47368421052631576
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateRoaming.cs, what happens when the beast reaches its current roaming point?
# a)It will stay at the point and wait for the player.
# b)It will teleport to a new roaming point.
# c)It will get a new roaming point and start moving towards it.
# d)It will change its state to OnTarget.
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (navMeshAgent.remainingDistance < 1.5f) {
#   navMeshAgent.SetDestination(BeastManager.BeastSpawnOnMeshPos.position);
# }
# ```
#
# ```csharp
# if (navMeshAgent.remaining
# LLM Answer:
# c)It will get a new roaming point and start moving towards it.
# Answer:c
# correct
# Progress: 0.07434944237918216
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateRoaming.cs, what does the beast do when it hears the player making sound?
# a)It will change its state to OnTarget.
# b)It will ignore the sound and continue roaming.
# c)It will roam to the player's last heard position.
# d)It will increase the detection angle.
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (navMeshAgent.enabled) navMeshAgent.enabled = false;
# ```
#
# ```csharp
# if (navMeshAgent.enabled) navMeshAgent.enabled = true;
# ```
#
# ```csharp
# navMeshAgent.SetDestination(player.position);
# LLM Answer:
# b)It will ignore the sound and continue roaming.
#
# Answer:b.
# wrong
# Progress: 0.07806691449814127
# Accuracy: 0.47619047619047616
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateScaping.cs, what is the purpose of the Update() method?
# a)To check if the beast has reached its hiding place
# b)To change the beast's state
# c)To make the beast look at the player
# d)To set the beast's destination
# first think step by step
#
# LLM Answer:
#  ```csharp
# To change the beast's state
# ```
# Answer: b.
#
# Explanation:
# The Update() method is called once per frame. In this case, it is used to change the beast's state. If the beast reaches its hiding place, it will change its state to BeastManager.State.Roaming. Otherwise, it will
# wrong
# Progress: 0.08178438661710037
# Accuracy: 0.45454545454545453
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateScaping.cs, when does the beast change to the Sleep state?
# a)When the beast reaches its hideout
# b)When the player brings the power back on
# c)When the beast is out
# d)When the player turns off the power
# first think step by step
#
# LLM Answer:
#  ```csharp
# if (navMeshAgent.remainingDistance < distanceToHideout) {
#   navMeshAgent.speed = normalSpeed;
#   navMeshAgent.enabled = true;
#   navMeshAgent.SetDestination(BeastManager.BeastSleepPos.position);
#   return;
# }
# ```
#
# ```csharp
# if (navMeshAgent.rem
# LLM Answer:
# a)When the beast reaches its hideout
# Answer:a
# correct
# Progress: 0.08550185873605948
# Accuracy: 0.4782608695652174
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateScaping.cs, what happens when the OnStateActivated() method is called?
# a)The beast's destination is set to its hideout position
# b)The beast's speed is set to normal
# c)The beast's state is changed to Sleep
# d)The beast is teleported to its hideout
# first think step by step
#
# LLM Answer:
#  ```csharp
# //set the destination to the beast's hideout position
# navMeshAgent.SetDestination(BeastManager.BeastSleepPos.position);
# ```
#
# ```csharp
# //set the beast's speed to normal
# navMeshAgent.speed = normalSpeed;
# ```
# LLM Answer:
# a)The beast's destination is set to its hideout position
#
# Answer:a
# correct
# Progress: 0.08921933085501858
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Within the BeastStateSleep class, what is the purpose of the OnStateActivated method?
# a)To enable the NavMeshAgent component.
# b)To move the beast to its hideout position.
# c)To set the beast's speed.
# d)To deactivate the beast's gameObject.
# first think step by step
#
# LLM Answer:
#  ```csharp
# //set the navMeshAgent speed to 0
# navMeshAgent.speed = 0;
# ```
#
# ```csharp
# //move the beast to its hideout position
# transform.DOMove(beastTransform.position.normalize() * hideoutDistance, 1f).OnComplete((() => {

# %% [markdown]
# --------------------------
