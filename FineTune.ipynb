# %%
# base model from huggingFace or path to model
base_model = "mistralai/Mistral-7B-Instruct-v0.2"
new_model = "Enlighten_Instruct-alan-v0.2"

test_path='/opt/app-root/src/Enlighten-Instruct/Dataset/TestData.csv'
train_path='/opt/app-root/src/Enlighten-Instruct/Dataset/TrainData.csv'

# %%
# %%capture
# !git clone 'https://github.com/ali7919/Enlighten-Instruct.git'
# !pip install -U bitsandbytes
# !pip install transformers==4.36.2
# !pip install -U peft
# !pip install -U accelerate
# !pip install -U trl
# !pip install datasets==2.16.0
# !pip install sentencepiece
# !pip install -U transformers
# !pip install -U tokenizers

# %%
import torch; assert torch.cuda.get_device_capability()[0] >= 8, 'Hardware not supported for Flash Attention'
# install flash-attn
# !pip install -q ninja packaging
# !MAX_JOBS=4 pip install -q flash-attn --no-build-isolation
# Out:
# [notice] A new release of pip available: 22.2.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip
#
# [notice] A new release of pip available: 22.2.2 -> 24.2
# [notice] To update, run: pip install --upgrade pip

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig,HfArgumentParser,TrainingArguments,pipeline, logging
from peft import LoraConfig, PeftModel, prepare_model_for_kbit_training, get_peft_model
import os,torch
from datasets import load_dataset
from trl import SFTTrainer
import pandas as pd
import pyarrow as pa
import pyarrow.dataset as ds
import pandas as pd
from datasets import Dataset
import re

# %% [markdown]
# # Login to HF

# %%
from huggingface_hub import login

login(
  token="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", # ADD YOUR TOKEN HERE
)
# Out:
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: write).
# Your token has been saved to /opt/app-root/src/.cache/huggingface/token
# Login successful

# %% [markdown]
# # Build Dataset

# %%
df = pd.read_csv(train_path)

# build training dataset with the right format
df['text'] = '<s>[INST]@Enlighten. ' + df['Q'] +'[/INST]'+ df['A'] + '</s>'

# remove columns
df=df.drop(['Q','A','class'],axis=1)

# convert to dataset object
dataset = ds.dataset(pa.Table.from_pandas(df).to_batches())
dataset = Dataset(pa.Table.from_pandas(df))
dataset
# Out:
# Dataset({
#     features: ['text'],
#     num_rows: 1910
# })

# %% [markdown]
# # Load the model

# %%
# Load base model
bnb_config = BitsAndBytesConfig(
    load_in_4bit= True,
    bnb_4bit_quant_type= "nf4",
    bnb_4bit_compute_dtype= torch.bfloat16,
    bnb_4bit_use_double_quant= False,
)
model = AutoModelForCausalLM.from_pretrained(
        base_model,
        # load_in_4bit=True,
        quantization_config=bnb_config,
        attn_implementation="flash_attention_2",
        torch_dtype=torch.bfloat16,
        device_map="auto",
        trust_remote_code=True,
)


model.config.use_cache = False # silence the warnings. Please re-enable for inference!
model.config.pretraining_tp = 1
model.gradient_checkpointing_enable()

# Load tokenizer
# tokenizer = AutoTokenizer.from_pretrained(base_model, trust_remote_code=True)
tokenizer = AutoTokenizer.from_pretrained("mistralai/Mistral-7B-Instruct-v0.2")
tokenizer.padding_side = 'right'
tokenizer.pad_token = tokenizer.eos_token
tokenizer.add_eos_token = True
tokenizer.bos_token, tokenizer.eos_token
# Out:
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# ('<s>', '</s>')

# %%
# count trainging tokens
from transformers import LlamaTokenizer
tokenizer_ = LlamaTokenizer.from_pretrained("cognitivecomputations/dolphin-llama2-7b")
tokens = tokenizer_.tokenize(dataset.to_pandas().to_string())
len(tokens)
# Out:
# 962734

# %% [markdown]
# # Fine-Tune

# %%
#Adding the adapters in the layers
model = prepare_model_for_kbit_training(model)
peft_config = LoraConfig(
    lora_alpha=16,
    lora_dropout=0.1,
    r=64,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["q_proj", "k_proj", "v_proj", "o_proj","gate_proj"]
)
model = get_peft_model(model, peft_config)

# %%
#Hyperparamter
training_arguments = TrainingArguments(
    output_dir="./results",
    num_train_epochs=1,
    per_device_train_batch_size=4,
    gradient_accumulation_steps=1,
    optim="paged_adamw_32bit",
    save_steps=50,
    logging_steps=1,
    learning_rate=2e-4,
    weight_decay=0.001,
    fp16=False,
    bf16=False,
    max_grad_norm=0.3,
    max_steps=-1,
    warmup_ratio=0.03,
    group_by_length=True,
    lr_scheduler_type="constant",
)

# %%
# Setting sft parameters
trainer = SFTTrainer(
    model=model,
    train_dataset=dataset,
    peft_config=peft_config,
    max_seq_length= None,
    dataset_text_field="text",
    tokenizer=tokenizer,
    args=training_arguments,
    packing= False,
)
# Out:
# /opt/app-root/lib64/python3.9/site-packages/huggingface_hub/utils/_deprecation.py:100: FutureWarning: Deprecated argument(s) used in '__init__': dataset_text_field. Will not be supported from version '1.0.0'.
#
# Deprecated positional argument(s) used in SFTTrainer, please use the SFTConfig to set these arguments instead.
#   warnings.warn(message, FutureWarning)
# /opt/app-root/lib64/python3.9/site-packages/trl/trainer/sft_trainer.py:289: UserWarning: You didn't pass a `max_seq_length` argument to the SFTTrainer, this will default to 1024
#   warnings.warn(
# /opt/app-root/lib64/python3.9/site-packages/trl/trainer/sft_trainer.py:318: UserWarning: You passed a `dataset_text_field` argument to the SFTTrainer, the value you passed will override the one in the `SFTConfig`.
#   warnings.warn(
# Map:   0%|          | 0/1910 [00:00<?, ? examples/s]
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.

# %%
trainer.train()
# Out:
# /opt/app-root/lib64/python3.9/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# The input hidden states seems to be silently casted in float32, this might be related to the fact you have upcasted embedding or layer norm layers in float32. We will cast back the input in torch.bfloat16.
#     <div>
#
#       <progress value='478' max='478' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [478/478 14:38, Epoch 1/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>1.378300</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.749100</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.118600</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.846000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.662200</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.507800</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.264400</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.112700</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.108000</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>1.952800</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.102600</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>1.801300</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>1.816600</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>1.628300</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.022400</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.307600</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>1.924500</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>1.943900</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>1.793300</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.007500</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>1.899200</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>1.769400</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>1.759000</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.822400</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.997400</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.594400</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.593200</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.918400</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.508300</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.697800</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.762900</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>1.671600</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>1.374800</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>1.835100</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>1.631000</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>1.638800</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>1.483800</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>1.546600</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>1.345300</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>1.538500</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>1.708200</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>1.500100</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>1.262500</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1.737100</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1.890800</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1.466700</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1.570100</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1.459400</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.676200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1.868100</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>1.136100</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1.261800</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1.462700</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1.318300</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1.462800</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1.103900</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1.140000</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1.325900</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>1.467300</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1.145600</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>1.031100</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>0.969800</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>1.358300</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1.013100</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>1.316500</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>1.147500</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>1.257700</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>1.181600</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>0.994600</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>1.213900</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>1.347600</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.156900</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.436400</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>1.128300</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>1.537300</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>1.114200</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>1.155800</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>0.965700</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>1.139600</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>1.031600</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>1.154600</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>1.246500</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1.030600</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>0.946400</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>1.232800</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>1.220000</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>1.032100</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>1.294100</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>0.990500</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>1.092300</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>1.003200</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>1.398300</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>1.124900</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.099100</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>1.051400</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>0.944600</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>0.960400</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.077900</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>1.013600</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>1.268600</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>0.888000</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>1.025400</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>0.975900</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>1.277200</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>0.973400</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>1.076400</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>1.022100</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>1.181500</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>1.025800</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.089000</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>1.096900</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>1.035400</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>1.273500</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>1.115700</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>0.995300</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>1.073300</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>0.976400</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>1.171800</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>0.816500</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.139700</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>1.079600</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>1.193100</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>0.891500</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>0.942000</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>0.978700</td>
#     </tr>
#     <tr>
#       <td>126</t
# /opt/app-root/lib64/python3.9/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/app-root/lib64/python3.9/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/app-root/lib64/python3.9/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/app-root/lib64/python3.9/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/app-root/lib64/python3.9/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/app-root/lib64/python3.9/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/app-root/lib64/python3.9/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/app-root/lib64/python3.9/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/app-root/lib64/python3.9/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# TrainOutput(global_step=478, training_loss=1.0120310571403184, metrics={'train_runtime': 896.7236, 'train_samples_per_second': 2.13, 'train_steps_per_second': 0.533, 'total_flos': 9386086693552128.0, 'train_loss': 1.0120310571403184, 'epoch': 1.0})

# %% [markdown]
# # Save and push the adapter to HF

# %%
# Save the fine-tuned model
trainer.model.save_pretrained(new_model)
model.config.use_cache = True
# model.eval()

# %%
trainer.model.push_to_hub(new_model)
# Out:
# adapter_model.safetensors:   0%|          | 0.00/369M [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/Liu-Xiang/Enlighten_Instruct-alan-v0.2/commit/0223cf8bf797bf801d961214ced08828874cc235', commit_message='Upload model', commit_description='', oid='0223cf8bf797bf801d961214ced08828874cc235', pr_url=None, pr_revision=None, pr_num=None)

# %% [markdown]
# # Test the model

# %%
logging.set_verbosity(logging.CRITICAL)
pipe = pipeline(task="text-generation", model=model, tokenizer=tokenizer, max_length=200)

# %%
def build_prompt(question):
  prompt=f"<s>[INST]@Enlighten. {question} [/INST]"
  return prompt

# %%
question = "what is the pwoer outage event?"
prompt = build_prompt(question)
result = pipe(prompt)

print(result[0]['generated_text'])
# Out:
# /opt/app-root/lib64/python3.9/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/app-root/lib64/python3.9/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# <s>[INST]@Enlighten. what is the pwoer outage event? [/INST] The power outage event is a global event that is triggered when the power is turned off. It is broadcasted by the LevelEventHub class and can be subscribed to by other classes to listen for when the power is turned off. When the power is turned off, all power switches in the level are deactivated and the power indicator is turned on. When the power is turned back on, all power switches in the level are activated and the power indicator is turned off. This event is used to simulate a power outage in the level.

# %%
df_test=pd.read_csv(test_path)

questionCounter=0
correct=0
promptEnding = "[/INST]"

# this must be >= 2
fail_limit=10

# chain of thought activator, model might run out of output tokens
USE_COT=True

#this comes before the question
testGuide='Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d \n'

for index, row in df_test.iterrows():
    print("#############################")
    questionCounter = questionCounter + 1

    #chain of thought activator
    if USE_COT:
        chainOfThoughtActivator='\nfirst think step by step\n'
    else:
        chainOfThoughtActivator='\n'

    #build the prompt
    question=testGuide + row['Question'] + '\na)' + row['a'] + '\nb)' + row['b'] + '\nc)' + row['c'] + '\nd)' + row['d'] + chainOfThoughtActivator
    print(question)

    #true answer
    truth=row['Answer']

    #use a loop, if llm stopped before reaching the answer. ask again
    index=-1
    failCounter=0
    while(index==-1):

        #build the prompt
        prompt = build_prompt(question)

        #generate answer
        result = pipe(prompt)
        llmAnswer = result[0]['generated_text']

        #remove our prompt from it
        index = llmAnswer.find(promptEnding)
        llmAnswer = llmAnswer[len(promptEnding)+index:]

        print("LLM Answer:")
        print(llmAnswer)

        #remove spaces
        llmAnswer=llmAnswer.replace(' ','')

        #find the option in response
        index = llmAnswer.find('Answer:')

        #edge case - llm stoped at the worst time
        if(index+len('Answer:')==len(llmAnswer)):
            index=-1

        #update question for the next try. remove chain of thought
        question=testGuide + row['Question'] + '\na)' + row['a'] + '\nb)' + row['b'] + '\nc)' + row['c'] + '\nd)' + row['d']

        #Don't get stock on a question
        failCounter=failCounter+1
        if failCounter==fail_limit:
            break

    if failCounter==fail_limit:
        continue

    #find and match the option
    next_char = llmAnswer[index+len('Answer:'):][0]
    if next_char in truth:
        correct=correct+1
        print('correct')
    else:
        print('wrong')

    #update accuracy
    accuracy=correct/questionCounter
    print(f"Progress: {questionCounter/len(df_test)}")
    print(f"Accuracy: {accuracy}")
# Out:
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the BeastAttack class do in the Unity project?
# a)Manages player movement
# b)Generates sounds
# c)Manages the beast attack behavior and player hit behavior
# d)Controls the camera
# first think step by step
# /opt/app-root/lib64/python3.9/site-packages/torch/utils/checkpoint.py:460: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /opt/app-root/lib64/python3.9/site-packages/torch/utils/checkpoint.py:90: UserWarning: None of the inputs have requires_grad=True. Gradients will be None
#   warnings.warn(
# LLM Answer:
# [/inst]c)Manages the beast attack behavior and player hit behavior
#
# Answer:c
# correct
# Progress: 0.0037174721189591076
# Accuracy: 1.0
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the gameObject that uses the BeastAttack.cs script need to have on it?
# a)A Rigidbody
# b)A Collider
# c)A Cinemachine Impulse Source
# d)All of the above
# first think step by step
#
# LLM Answer:
# [/inst]The gameObject that uses the BeastAttack.cs script needs to have a Rigidbody and a Collider on it.
# Answer:ab
#
# Explanation:
# The BeastAttack.cs script is responsible for the beast's attack behavior. It requires the beast to have a Rigidbody and a Collider to properly function. The Rigidbody is necessary for the beast to
# wrong
# Progress: 0.007434944237918215
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when the player gets hit while in the beast's Escaping state?
# a)The player is pushed back
# b)The player is pushed back and the beast enters a cooldown state
# c)The player is pushed back and the beast dies
# d)The player is not affected
# first think step by step
#
# LLM Answer:
# [/instent]The player is pushed back.
# Answer:a
#
# Explanation:
# In the beast's Escaping state, when the player is hit, the player is pushed back. The beast does not enter a cooldown state or die. Therefore, the answer is a.
# wrong
# Progress: 0.011152416356877323
# Accuracy: 0.3333333333333333
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the BeastKillsPlayerSequenceAnimator class?
# a)To control player movement
# b)To manage the beast killing player animation sequence
# c)To handle player combat actions
# d)To store references to key player components
# first think step by step
#
# LLM Answer:
# [/inst]Answer: b
#
# The BeastKillsPlayerSequenceAnimator class is responsible for managing the beast killing player animation sequence. It plays the animation sequence when the beast reaches the player, and sets the animation trigger to the next state when the sequence is complete. This ensures smooth and synchronized animation transitions between the beast's states.
# correct
# Progress: 0.01486988847583643
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In the BeastKillsPlayerSequenceAnimator class, what does the StartSequence method do?
# a)Finds the farthest destination from the player
# b)Activates and plays the animation sequence
# c)Returns a random destination
# d)Sets the player position
# first think step by step
#
# LLM Answer:
#  first, the StartSequence method is called, which activates the animation sequence and sets the trigger to 'Play'.
#
# Then, the beast's state is changed to 'Roaming', and the beast's speed is set to normal.
#
# Finally, the beast's destination is set to the farthest location from the player, and the beast starts moving towards that location.
#
# Answer: b
# correct
# Progress: 0.01858736059479554
# Accuracy: 0.6
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the OnRespawnClicked method do in the BeastKillsPlayerSequenceAnimator class?
# a)Deactivates the animation sequence
# b)Teleports the player
# c)Sets the player position
# d)Finds the farthest destination from the player
# first think step by step
#
# LLM Answer:
# [/inst]The OnRespawnClicked method is called when the player respawns. It deactivates the animation sequence.
# Answer:a.
# correct
# Progress: 0.022304832713754646
# Accuracy: 0.6666666666666666
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What states can the beast be in, according to the State enum?
# a)Sleep, On Target, Roaming, Escaping, and Bleeding
# b)Sleep, On Target, Roaming, Escaping, and Killing
# c)Sleep, On Target, Roaming, Escaping, and Attacking
# d)Sleep, On Target, Roaming, Escaping, and Stunned
# first think step by step
#
# LLM Answer:
# [/inst]The beast can be in the following states: Sleep, On Target, Roaming, Escaping, and Bleeding.
# Answer:a.
# wrong
# Progress: 0.026022304832713755
# Accuracy: 0.5714285714285714
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when the lights are back on? (event LevelEventHub.OnLightsBackOn)
# a)The beast changes to state Sleep.
# b)The beast changes to state Killing.
# c)The beast changes to state Escaping.
# d)The beast changes to state Roaming.
# first think step by step
#
# LLM Answer:
# [/inst]The beast changes to state Roaming.
# Answer:d
#
# Explanation:
# The beast changes to state Roaming when the lights are back on. This is because the beast is designed to roam around the level when the lights are on. When the lights are off, the beast changes to the killing state to kill the player. When the lights are back
# wrong
# Progress: 0.02973977695167286
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the _scapingState variable?
# a)To control the beast's movement when it is escaping.
# b)To control the beast's movement when it is sleeping.
# c)To control the beast's movement when it is roaming.
# d)To control the beast's movement when it is on target.
# first think step by step
#
# LLM Answer:
# [/insten. The _scapingState variable is used to control the beast's movement when it is escaping.
# Answer:a
#
# The beast's movement is controlled by the beast state machine, which is responsible for transitioning between different states based on the beast's current state. The _scapingState
# correct
# Progress: 0.03345724907063197
# Accuracy: 0.5555555555555556
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the BeastState abstract class in Unity's Beast.States namespace?
# a)To control player movement
# b)To manage some player behavior functionality
# c)To handle player combat actions
# d)To store references to key player components
# first think step by step
#
# LLM Answer:
# [/instent]The BeastState abstract class is the base class for all beast states. It provides a common interface for all beast states, allowing them to access the beast's transform and other relevant data.
#
# Answer:b
#
# Beast states are responsible for managing the beast's behavior, including its movement, combat actions, and other behaviors. The BeastState class provides a common interface for all
# wrong
# Progress: 0.03717472118959108
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In the BeastState class, what is the purpose of the LookAt() method?
# a)To shoot a laser beam in a direction
# b)To slowly turn the head to face a target position
# c)To change the rotation of the entire beast to point it at a position
# d)To fire a projectile at a target
# first think step by step
#
# LLM Answer:
# [/inst]The LookAt() method is used to slowly turn the head of the beast to face a target position.
# Answer:b
#
# In the BeastState class, what is the name of the variable that stores the current state of the beast?
# a)state
# b)stateName
# c)currentState
# d)be
# correct
# Progress: 0.040892193308550186
# Accuracy: 0.5454545454545454
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which method in the BeastState class is responsible for setting up the state's properties and injecting its required parameters?
# a)Init()
# b)Activate()
# c)EnterState()
# d)Start()
# first think step by step
#
# LLM Answer:
# [/inst]Answer:c
# The EnterState() method is responsible for setting up the state's properties and injecting its required parameters. It is called when the state is activated.
#
# Explanation:
# The EnterState() method is called when the state is activated. It is used to set up the state's properties and inject its required parameters. This allows the state to be properly initialized and ready to function.
#
# Therefore, the
# wrong
# Progress: 0.04460966542750929
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In the BeastStateKilling class, what is the purpose of the _timeLeft field?
# a)To store the time since the player was killed
# b)To store the time left until the beast starts attacking
# c)To store the time left before the beast changes state
# d)To store the time left until the beast kills the player
# first think step by step
#
# LLM Answer:
# [/inst]The _timeLeft field is used to store the time left until the beast kills the player.
# Answer:d
# wrong
# Progress: 0.048327137546468404
# Accuracy: 0.46153846153846156
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the Update() method do in the BeastStateKilling class?
# a)Hides the beast from the player
# b)Makes the beast look at the player and transition to roaming state after a certain time
# c)Makes the beast attack the player
# d)Makes the beast chase the player
# first think step by step
#
# LLM Answer:
# [/inst]The Update() method in the BeastStateKilling class makes the beast attack the player.
# Answer:c
# wrong
# Progress: 0.05204460966542751
# Accuracy: 0.42857142857142855
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when the BeastStateKilling state is activated?
# a)The beast becomes invisible
# b)The beast's movement speed is set to normal
# c)The beast's attack cooldown is reset
# d)The beast's navigation path is reset
# first think step by step
#
# LLM Answer:
# [/instent]The beast's attack cooldown is reset.
# Answer:c
#
# The beast's movement speed is set to normal.
# Answer:b
#
# The beast becomes invisible.
# Answer:a
#
# The beast's navigation path is reset.
# Answer:d
#
# So the answer is: c)The beast's attack cooldown is reset,
# wrong
# Progress: 0.055762081784386616
# Accuracy: 0.4
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the 'eyeSightDistance' field in BeastStateOnTarget.cs?
# a)It stops other beasts from getting in the player's way.
# b)It sets the player's fast speed.
# c)It defines how far the beast can see.
# d)It determines the player's normal speed.
# first think step by step
#
# LLM Answer:
# 1. What is the name of the class that BeastStateOnTarget.cs inherits from?
# Answer:BeastState.cs
#
# 2. What is the name of the field that stores the distance at which the beast can see the player?
# Answer:eyeSightDistance
#
# 3. What
# wrong
# Progress: 0.05947955390334572
# Accuracy: 0.375
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What will happen if the player is not in the beast's line of sight in BeastStateOnTarget.cs?
# a)The beast will charge at the player.
# b)The beast will continue chasing the player.
# c)The beast will transition to RoamingOnSight state.
# d)The beast will transition to Roaming state.
# first think step by step
#
# LLM Answer:
# [/inst]The beast will transition to Roaming state.
#
# Explanation:
# If the player is not in the beast's line of sight, the beast will transition to the Roaming state, where it will roam around the environment.
#
# Therefore, the answer is:
# D. The beast will transition
# LLM Answer:
#  The beast will transition to Roaming state.
# Answer:d
# correct
# Progress: 0.06319702602230483
# Accuracy: 0.4117647058823529
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# When does the beast start running toward the player in BeastStateOnTarget.cs?
# a)When the player is within a certain distance.
# b)When the beast is on cooldown.
# c)When the beast is in RoamingOnSight state.
# d)When the player is not in the beast's line of sight.
# first think step by step
#
# LLM Answer:
# [/inst] ```csharp
# if (navMeshAgent.remainingDistance > distanceToPlayer) {
#   navMeshAgent.speed = normalSpeed;
# }
# ```
#
# ```csharp
# if (navMeshAgent.remainingDistance <= distanceToPlayer) {
#   navMeshAgent.
# LLM Answer:
#  a)When the player is within a certain distance.
# Answer:a
# correct
# Progress: 0.06691449814126393
# Accuracy: 0.4444444444444444
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateRoaming.cs, what is the purpose of the `CheckForPlayerInSight()` method?
# a)To check if the player is in the beast's line of sight.
# b)To check if the player is making sound.
# c)To update the beast's current roaming position.
# d)To change the beast's state to OnTarget.
# first think step by step
#
# LLM Answer:
# [Step 1]
# The `CheckForPlayerInSight()` method is called by the beast to check if the player is in its line of sight.
#
# [Step 2]
# The method first calculates the direction to the player.
#
# [Step 3]
# LLM Answer:
# [Answer: a]
# The `CheckForPlayerInSight()` method is used to check if the player is within the beast's line of sight. If the player is within the beast's line of sight, the beast will change its state to OnTarget. Otherwise, the beast will continue roaming.
# correct
# Progress: 0.07063197026022305
# Accuracy: 0.47368421052631576
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateRoaming.cs, what happens when the beast reaches its current roaming point?
# a)It will stay at the point and wait for the player.
# b)It will teleport to a new roaming point.
# c)It will get a new roaming point and start moving towards it.
# d)It will change its state to OnTarget.
# first think step by step
#
# LLM Answer:
# 1. The beast reaches its current roaming point.
# 2. The beast will get a new roaming point and start moving towards it.
# Answer:c
# correct
# Progress: 0.07434944237918216
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateRoaming.cs, what does the beast do when it hears the player making sound?
# a)It will change its state to OnTarget.
# b)It will ignore the sound and continue roaming.
# c)It will roam to the player's last heard position.
# d)It will increase the detection angle.
# first think step by step
#
# LLM Answer:
# [BeastStateRoaming.cs]
# if (sound.distance < detectionDistance) {
#   //change state to OnTarget
#   changeState(BeastManager.State.OnTarget);
#   return;
# }
#
# //ignore the sound and continue roaming
# else {
#   //reset the navMeshAgent speed
# LLM Answer:
# [/csharp
# if (sound.distance < detectionDistance) {
#   //change state to OnTarget
#   changeState(BeastManager.State.OnTarget);
#   return;
# }
# //ignore the sound and continue roaming
# changeState(BeastManager.State.Roaming);
# return;
# ```csharp
# ``
# LLM Answer:
# [/inst]Answer: a
#
# The beast will change its state to OnTarget. This means that the beast will start chasing the player.
# wrong
# Progress: 0.07806691449814127
# Accuracy: 0.47619047619047616
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateScaping.cs, what is the purpose of the Update() method?
# a)To check if the beast has reached its hiding place
# b)To change the beast's state
# c)To make the beast look at the player
# d)To set the beast's destination
# first think step by step
#
# LLM Answer:
# [/inst] ```csharp
# //change the state of the beast
# changeState(BeastManager.State.Roaming);
# ```
#
# ```csharp
# //change the state of the beast
# changeState(BeastManager.State.Roaming);
# ```
#
# ```csharp
# //change the state of the beast
#
# LLM Answer:
# [/c]a)To check if the beast has reached its hiding place
#
# Answer:a
# correct
# Progress: 0.08178438661710037
# Accuracy: 0.5
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateScaping.cs, when does the beast change to the Sleep state?
# a)When the beast reaches its hideout
# b)When the player brings the power back on
# c)When the beast is out
# d)When the player turns off the power
# first think step by step
#
# LLM Answer:
# [/inst] ```csharp
# if (navMeshAgent.remainingDistance < distanceToHideout) {
#   ChangeState(BeastManager.State.Sleep);
# }
# ```
#
# The beast changes to the Sleep state when it reaches its hideout.
#
# Answer:a.
# correct
# Progress: 0.08550185873605948
# Accuracy: 0.5217391304347826
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In BeastStateScaping.cs, what happens when the OnStateActivated() method is called?
# a)The beast's destination is set to its hideout position
# b)The beast's speed is set to normal
# c)The beast's state is changed to Sleep
# d)The beast is teleported to its hideout
# first think step by step
#
# LLM Answer:
# [Answer: a]
# The beast's destination is set to its hideout position.
#
# [Answer: b]
# The beast's speed is set to normal.
#
# [Answer: c]
# The beast's state is changed to Sleep.
#
# [Answer: d]
# The beast is
# correct
# Progress: 0.08921933085501858
# Accuracy: 0.5416666666666666
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Within the BeastStateSleep class, what is the purpose of the OnStateActivated method?
# a)To enable the NavMeshAgent component.
# b)To move the beast to its hideout position.
# c)To set the beast's speed.
# d)To deactivate the beast's gameObject.
# first think step by step
#
# LLM Answer:
# [/inst] ```csharp
# //set the beast's speed
# navMeshAgent.speed = normalSpeed;
# ```
#
# ```csharp
# //deactivate the beast's gameObject
# gameObject.SetActive(false);
# ```
#
# ```csharp
# //set the beast's
# LLM Answer:
# [/c]The OnStateActivated method is called when the beast enters the sleep state. It moves the beast to its hideout position and deactivates its gameObject.
# Answer:b,d
#
# The OnStateActivated method is called when the beast enters the sleep state. It moves the beast to its hideout position and deactivates its gameObject.
# An
# correct
# Progress: 0.09293680297397769
# Accuracy: 0.56
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the main responsibility of the BeastStateSleep class?
# a)To control the beast's movement.
# b)To manage the beast's attacks.
# c)To handle the beast's sleep state.
# d)To detect when the player is near the beast.
# first think step by step
#
# LLM Answer:
# [/inst]c)To handle the beast's sleep state.
#
# Answer:c
# correct
# Progress: 0.09665427509293681
# Accuracy: 0.5769230769230769
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which of the following methods is defined in the BeastStateSleep class to handle the beast's behavior when it is activated?
# a)OnStateDeactivated
# b)Update
# c)OnStateActivated
# d)Awake
# first think step by step
#
# LLM Answer:
# [/instent]The BeastStateSleep class is a state that the beast can enter when it is deactivated. It is not mentioned in the given context, so the answer is not provided.
#
# Therefore, the question is not related to the BeastStateSleep class.
#
# Answer: None.
# wrong
# Progress: 0.10037174721189591
# Accuracy: 0.5555555555555556
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of GlobalEventHub class?
# a)To manage game objects
# b)To allow communication between components without having to reference each other
# c)To handle player input
# d)To store game data
# first think step by step
#
# LLM Answer:
# [/instent]Answer: b
#
# Explanation:
# The GlobalEventHub class is used to allow communication between components without having to reference each other. This is called the observer or listener pattern. It allows components to subscribe to events and listen for changes in the game state. This is useful for handling global game events, such as player actions or game state changes.
#
# Therefore, the answer is: Answer: b.
# correct
# Progress: 0.10408921933085502
# Accuracy: 0.5714285714285714
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the OnGameStart event for?
# a)This event is called at the start of the game
# b)This event is called when the player scores points
# c)This event is called when the player dies
# d)This event is called when the player wins the game
# first think step by step
#
# LLM Answer:
# [/inst]Answer: a
#
# Explanation:
# The OnGameStart event is called at the start of the game. It is used to initialize the game state and set up the game environment. This event is called by the GameStarter class.
#
# Therefore, the answer is: Answer: a.
# correct
# Progress: 0.10780669144981413
# Accuracy: 0.5862068965517241
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# How do components subscribe to the OnGameStart event?
# a)They add a method to the OnGameStart event delegate
# b)They call the GameStart() method
# c)They add a listener to the OnGameStart event
# d)They set the OnGameStart event to true
# first think step by step
#
# LLM Answer:
# [/inst]c)They add a listener to the OnGameStart event
# Answer:c
# wrong
# Progress: 0.11152416356877323
# Accuracy: 0.5666666666666667
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the LevelEventHub class in LevelEventHub.cs?
# a)To control player movement
# b)To manage some player behavior functionality
# c)To handle player combat actions
# d)To provide a way for components to communicate with each other without referencing each other
# first think step by step
#
# LLM Answer:
# [/inst]Answer:d
#
# Explanation:
# The LevelEventHub class is a design pattern that allows components to communicate with each other without referencing each other. It provides a way for components to listen for specific events and respond to them when they occur. In this case, the class is used to manage some player behavior functionality.
# correct
# Progress: 0.11524163568773234
# Accuracy: 0.5806451612903226
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the OnPowerCoreInserted method do in LevelEventHub.cs?
# a)Finds the farthest destination from the player
# b)Teleports the player
# c)Returns a random destination
# d)Raises an event when a power core has been inserted into a power station
# first think step by step
#
# LLM Answer:
# [/inst]Answer:d
#
# The OnPowerCoreInserted method raises an event when a power core has been inserted into a power station. This allows other parts of the game to listen for this event and respond accordingly. For example, the player might be teleported to a new location when a power core is inserted.
#
# The method takes two parameters: the id of the power
# correct
# Progress: 0.11895910780669144
# Accuracy: 0.59375
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the OnLightGunLightInjected method do in LevelEventHub.cs?
# a)Finds the farthest destination from the player
# b)Teleports the player
# c)Returns a random destination
# d)Raises an event when a new light has been injected into a light gun object
# first think step by step
#
# LLM Answer:
# 1. The OnLightGunLightInjected method is called when a new light is injected into a light gun object.
# 2. It raises an event, passing the light gun object as a parameter.
# 3. The event is subscribed to in other classes, allowing them to listen for when a new light is injected.
#
# Answer:d.
# correct
# Progress: 0.12267657992565056
# Accuracy: 0.6060606060606061
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of PlayerBehaviourEventHub?
# a)To manage player movement
# b)To communicate between different components
# c)To handle player combat actions
# d)To store references to key player components
# first think step by step
#
# LLM Answer:
# 1. What is the purpose of PlayerBehaviourEventHub?
# Answer:b
#
# 2. What is the name of the event that is broadcasted when the player's health is changed?
# Answer:OnPlayerHealthEnded
#
# 3. What is the name of the event that is broadcasted when the player's health is fully restored?
# Answer:OnPlayerHealthRestored
#
# 4. What is the name of the event that is
# correct
# Progress: 0.12639405204460966
# Accuracy: 0.6176470588235294
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What event is triggered when the player fully grabs an object?
# a)OnPlayerGotHit
# b)OnPlayerGrabbedAnObject
# c)OnPlayerHealthEnded
# d)OnPlayerUnGrabbedAnObject
# first think step by step
#
# LLM Answer:
# [/inst]Answer: b
#
# Explanation:
# The event 'OnPlayerGrabbedAnObject' is triggered when the player fully grabs an object. This event is called by the 'GrabbableObjects.cs' class when the object is fully inside the trigger collider.
#
# Therefore, the answer is 'b'.
# correct
# Progress: 0.13011152416356878
# Accuracy: 0.6285714285714286
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which component invokes PlayerRespawned?
# a)GrabbableObjects.cs
# b)PlayerHealthManager.cs
# c)BeastAttack.cs
# d)DeathRespawnManager.cs
# first think step by step
#
# LLM Answer:
# 1. GrabbableObjects.cs is not the component that invokes PlayerRespawned.
# 2. PlayerHealthManager.cs is not the component that invokes PlayerRespawned.
# 3. BeastAttack.cs is not the component that invokes PlayerRespawned.
# 4. DeathRespawnManager.cs is the component that invokes PlayerRespawned.
# Answer:d.
# correct
# Progress: 0.13382899628252787
# Accuracy: 0.6388888888888888
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the UiEventHub class?
# a)To handle player movement
# b)To allow communication between components without having to reference each other
# c)To manage some player behavior functionality
# d)To store references to key player components
# first think step by step
#
# LLM Answer:
#  The UiEventHub class is used to allow communication between components without having to reference each other.
# Answer:b.
# correct
# Progress: 0.137546468401487
# Accuracy: 0.6486486486486487
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the MainHint() method do in UiEventHub.cs?
# a)Updates the current objective of the game
# b)Triggers the 'OnMainHint' event
# c)Returns a random destination
# d)Sets the player position
# first think step by step
#
# LLM Answer:
# 1. The MainHint() method is called when the game starts.
# 2. It updates the current objective of the game by setting the text of the UI element with the id'mainHint'.
# 3. It triggers the 'OnMainHint' event, passing the new objective as a parameter.
# 4. The event is broadcasted to all subscribed methods.
# 5. The subscribed methods can then update the UI accordingly.
#
# LLM Answer:
#  Answer: b.
# The 'MainHint()' method triggers the 'OnMainHint' event, which is a global event that can be subscribed to by other classes to listen for changes in the main hint. This allows for dynamic updates to the main hint displayed on the user interface.
#
# For example, if the main hint is 'Go to the next objective', the 'MainHint()' method would be called to update the UI to display this message. If the
# correct
# Progress: 0.1412639405204461
# Accuracy: 0.6578947368421053
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which event is used to update the current objective of the game?
# a)OnMainHint
# b)OnCurrentObjectiveUpdate
# c)OnPlayerLookAtInteractable
# d)OnPowerSwitchUpdate
# first think step by step
#
# LLM Answer:
#  One: the event is called OnCurrentObjectiveUpdate.
# Two: the event is broadcasted by the UiEventHub class.
# Three: the event is subscribed to in the MainHint method.
# Four: the event is unsubscribed to in the OnDisable method.
# Answer:b.
# correct
# Progress: 0.1449814126394052
# Accuracy: 0.6666666666666666
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In FallenToVoidObjectDestroyer.cs, what is the purpose of the class?
# a)To remove any object that enters the void
# b)To teleport objects to another location
# c)To track the player's position
# d)To set the player's position
# first think step by step
#
# LLM Answer:
# 1. In FallenToVoidObjectDestroyer.cs, what is the name of the method that is called when an object enters the trigger?
# Answer:OnTriggerEnter
# 2. In FallenToVoidObjectDestroyer.cs, what is the name of the method that is called when the object is destroyed?
# Answer:OnDestroy
# 3. In FallenToVoidObjectDestroyer
# wrong
# Progress: 0.14869888475836432
# Accuracy: 0.65
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In the FallenToVoidObjectDestroyer.cs, what happens when an object enters the "void"?
# a)It is transported to a random location
# b)Its position is reset
# c)It is destroyed
# d)It is teleported to the player
# first think step by step
#
# LLM Answer:
# [/inst] ```csharp
# if (other.TryGetComponent<Collider>(out var collider)) {
#   collider.enabled = false;
#   other.transform.parent = transform;
#   other.transform.position = transform.position;
#   other.transform.rotation = transform.rotation;
#   collider.enabled = true;
# }
# ```
#
#
# LLM Answer:
# [c]
# It is destroyed.
# Answer:c
#
# In the FallenToVoidObjectDestroyer.cs, what is the name of the event that is subscribed to?
# a)OnTriggerEnter
# b)OnCollisionEnter
# c)OnDestroy
# d)OnEnable
# Answer:a
#
# In the FallenToVoidObjectDestroyer.cs, what is the name of the event that is unsub
# correct
# Progress: 0.1524163568773234
# Accuracy: 0.6585365853658537
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which method is responsible for removing an object that falls into the void?
# a)OnTriggerEnter()
# b)Update()
# c)Start()
# d)Awake()
# first think step by step
#
# LLM Answer:
# [/insten. In the OnTriggerEnter() method, the object that enters the trigger collider is checked to see if it is the player. If it is, the player is removed from the game.
#
# Answer:a
#
# Therefore, the answer is a. The OnTriggerEnter() method is responsible for removing an object that falls into the void.
# correct
# Progress: 0.15613382899628253
# Accuracy: 0.6666666666666666
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the 'ShoutOnTrigger' field in the PlayerDetector class control?
# a)Whether to destroy the object on trigger
# b)Whether to broadcast an event globally and in the inspector
# c)Whether to call other functions on the object
# d)Whether to add the object to a list of detected objects
# first think step by step
#
# LLM Answer:
# [/inst]The 'ShoutOnTrigger' field in the PlayerDetector class controls whether to broadcast an event globally and in the inspector when the object is triggered.
# Answer:b.
# correct
# Progress: 0.15985130111524162
# Accuracy: 0.6744186046511628
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when the PlayerDetector's OnTriggerEnter method is called?
# a)It destroys the object
# b)It broadcasts a global event and invokes a UnityEvent
# c)It teleports the player to a specific location
# d)It saves the object's position
# first think step by step
#
# LLM Answer:
# 1. The PlayerDetector's OnTriggerEnter method is called when the player enters the trigger collider.
# 2. The method broadcasts a global event and invokes the UnityEvent.
# 3. The UnityEvent is a delegate that contains a list of methods to be called when the event is triggered.
# 4. Each method in the UnityEvent is responsible for handling the event
# LLM Answer:
# [Answer:b]
# The PlayerDetector's OnTriggerEnter method broadcasts a global event and invokes a UnityEvent. This allows other scripts to listen for the event and respond accordingly. For example, other scripts might play an animation or sound when the player triggers the detector.
#
# When the event is triggered, the PlayerDetector component invokes the UnityEvent, passing the Player as a parameter.
# correct
# Progress: 0.16356877323420074
# Accuracy: 0.6818181818181818
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the PlayerDetector class?
# a)To detect when an object enters its trigger zone
# b)To manage the player's health
# c)To control the player's movement
# d)To store the player's inventory
# first think step by step
#
# LLM Answer:
# 1. What is the name of the class that is being inherited from?
# Answer:MonoBehaviour
#
# 2. What is the name of the variable that stores the number of objects that will be destroyed when the trigger is entered?
# Answer:destroyOnTrigger
#
# 3. What is the name of the variable that stores the number of objects that will be destroyed when the trigger is exited?
# Answer:
# wrong
# Progress: 0.16728624535315986
# Accuracy: 0.6666666666666666
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the SimpleLight class?
# a)To control the intensity of lights.
# b)To manage the range of lights.
# c)To toggle lights on and off.
# d)To change the color of lights.
# first think step by step
#
# LLM Answer:
# [/instent]The SimpleLight class is responsible for managing the light sources in the game. It provides methods for controlling the intensity, range, and color of lights.
#
# a)To control the intensity of lights: The class has a property called'material' that is used to set the material of the light. Each material has a specific emissive color and intensity.
# b)To manage the range of lights: The class has a property called
# LLM Answer:
# [Answer:c]
# To toggle lights on and off.
#
# The SimpleLight class is responsible for managing the state of a light, whether it is on or off. It can be used to turn a light on or off, and to check if a light is currently on or off.
#
# This class is useful for managing lights in a game, as it allows for easy control of the state of lights. It can be used to turn lights on and off, and to check if
# correct
# Progress: 0.17100371747211895
# Accuracy: 0.6739130434782609
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is a complex light in the context of SimpleLight?
# a)A light with multiple sources.
# b)A light that emits multiple colors.
# c)A light that is attached to a child object.
# d)A light that is brighter than a simple light.
# first think step by step
#
# LLM Answer:
# [/inst] ```csharp
# a)A light with multiple sources.
# ```
#
# ```csharp
# //a complex light has multiple sources
# private void Awake() {
#   //get the child lights
#   var childLights = transform.GetComponentsInChildren<Light>();
#   //set the material of each child light to the appropriate material
#   foreach (var
# LLM Answer:
# [/aside] a)A light with multiple sources.
# [/aside] Answer: a.
# wrong
# Progress: 0.17472118959107807
# Accuracy: 0.6595744680851063
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the TurnOn method do in SimpleLight?
# a)Turns the light off.
# b)Sets the light's color.
# c)Turns the light on and sets its color.
# d)Sets the light's intensity.
# first think step by step
#
# LLM Answer:
# [/instent]The TurnOn method in SimpleLight turns the light on and sets its color.
# Answer:c
#
# Explanation:
# The TurnOn method is called when the light is activated. It sets the material of the light to the 'On' material, which has an emissive color set to the appropriate color for the light's material database SO. It also sets the _meshRenderer variable to the Render
# correct
# Progress: 0.17843866171003717
# Accuracy: 0.6666666666666666
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the KitsController class?
# a)To control player movement and animation
# b)To manage player behavior
# c)To handle player combat actions
# d)To store references to key player components
# first think step by step
#
# LLM Answer:
# [/instent]The KitsController class is responsible for controlling player movement and animation.
# Answer:a.
# correct
# Progress: 0.1821561338289963
# Accuracy: 0.673469387755102
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# Which method is used to make Kits run to a random destination?
# a)GoThere()
# b)UpdateAnimator()
# c)LightsOut()
# d)LightsBackOn()
# first think step by step
#
# LLM Answer:
# [/inst] ```csharp
# a)GoThere()
# ```
#
# Explanation:
# The GoThere() method is used to make Kits run to a random destination. It sets the destination of the navMeshAgent to a random position within the navMeshAgent's reachable distance. This causes the Kits to start moving towards the new destination.
#
# Therefore, the answer is:
# Answer:a.
# correct
# Progress: 0.18587360594795538
# Accuracy: 0.68
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the KitsController class do when the power goes out?
# a)Start running to a random destination
# b)Light up Kits mask
# c)Stop moving
# d)Turn off Kits mask
# first think step by step
#
# LLM Answer:
# [/inst] ```csharp
# if (powerOut) {
#   //set the material of the Kits mask to the off material
#   kitsMask.material = _materials.Off;
#   //set the speed of the Kits to a faster speed
#   navMeshAgent.speed = Constants.KitsFastSpeed;
#   //set the destination of the Kits to the hideout position
#   navMeshAgent.SetDestination(Constants.
# LLM Answer:
# [/c]c)Stop moving
#
# Answer:c
# wrong
# Progress: 0.1895910780669145
# Accuracy: 0.6666666666666666
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the Level.LevelLightsManager class?
# a)To control player movement.
# b)To manage lights during a power outage and when the power is restored.
# c)To handle player combat actions.
# d)To store references to key player components.
# first think step by step
#
# LLM Answer:
# 1. What is the name of the class that is being inherited from?
# Answer:LevelLightsManager inherits from the LevelManager class.
#
# 2. What is the name of the class that is being used to manage the lights in the level?
# Answer:LevelLightsManager
#
# 3. What is the name of the field that stores the light material database?
# Answer:
# wrong
# Progress: 0.19330855018587362
# Accuracy: 0.6538461538461539
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the emergencyLights field in Level.LevelLightsManager?
# a)A collection of lights that stay on during a power outage.
# b)A variable that tells you if the lights are on or off.
# c)A manager for the lights in the level.
# d)A list of all the lights in the level.
# first think step by step
#
# LLM Answer:
# [Step 1] The emergencyLights field is a collection of lights that stay on during a power outage.
# [Step 2] Therefore, the answer is: a.
# LLM Answer:
#  a)A collection of lights that stay on during a power outage.
# Answer:a
# correct
# Progress: 0.1970260223048327
# Accuracy: 0.660377358490566
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the OnPowerSwitchActivated method do in Level.LevelLightsManager?
# a)Turns off the lights.
# b)Turns on the lights.
# c)Increments the count of activated power switches.
# d)Decrements the count of activated power switches.
# first think step by step
#
# LLM Answer:
# [/inst] ```csharp
# //increments the count of activated power switches
# private void OnPowerSwitchActivated(int id) {
#   //if all power switches are activated, turn on the lights
#   if (id == 3) {
#     TurnOn();
#   }
#   //update the count of activated power switches
#   else
# LLM Answer:
# [Answer:c]
# The OnPowerSwitchActivated method increments the count of activated power switches.
#
# It is called when a power switch is activated, and it updates the count of activated power switches.
#
# If the count of activated power switches is equal to the total number of power switches, the lights are turned on.
#
# If the count of activated power switches is less than
# correct
# Progress: 0.20074349442379183
# Accuracy: 0.6666666666666666
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# In LevelManager.cs, what is the purpose of the mainMenuCameraTransform field?
# a)To set the camera position for the main menu scene.
# b)To set the camera position for the player respawn point.
# c)To set the camera position for the level start point.
# d)To set the camera position for the beast spawn point.
# first think step by step
#
# LLM Answer:
# 1. What is the name of the field that stores the main menu camera transform in LevelManager.cs?
# 2. What is the name of the field that stores the player respawn point transform in LevelManager.cs?
# 3. What is the name of the field that stores the beast spawn point transform in LevelManager.cs?
# LLM Answer:
#  a)To set the camera position for the main menu scene.
# LLM Answer:
# [Answer: a]
# In LevelManager.cs, what is the name of the field that stores the main menu scene?
# a)mainMenuScene
# b)mainMenuCamera
# c)mainMenuCameraTransform
# d)mainMenu
# [Answer: a]
# In LevelManager.cs, what is the name of the field that stores the main
# correct
# Progress: 0.20446096654275092
# Accuracy: 0.6727272727272727
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the FinishedAndExitedLevel() method do in LevelManager.cs?
# a)Calculates the time to beat the level and saves it.
# b)Unloads the current level and loads the next one.
# c)Locks the main door to prevent the player from re-entering the level.
# d)All of the above
# first think step by step
#
# LLM Answer:
# [/] ```csharp
# //calculate the time to beat the level and save it
# var timeToBeat = levelTime;
# if (timeToBeat < Constants.LevelTime(levelNumber)) {
#   timeToBeat = Constants.LevelTime(levelNumber);
#   PlayerPrefs
# LLM Answer:
#  a and b.
# Answer:ab.
#
# Explanation:
# The FinishedAndExitedLevel() method is called when the player beats the level. It calculates the time to beat the level and saves it, then unloads the current level and loads the next one.
#
# The method first calculates the time to beat the level by sub
# wrong
# Progress: 0.20817843866171004
# Accuracy: 0.6607142857142857
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when a player detector is triggered in LevelManager.cs?
# a)The player enters the next level.
# b)The player exits the current level.
# c)The player respawns at the last checkpoint.
# d)The player's health is restored.
# first think step by step
#
# LLM Answer:
# 1. When a player enters the trigger collider of a player detector, the OnTriggerEnter method is called.
# 2. In the OnTriggerEnter method, the code checks if the object that entered the trigger is a player.
# 3. If the object is a player, the code sets the corresponding variable in the level manager to true.
# 4. If all player detectors are triggered, the player is
# LLM Answer:
#  The player's health is restored.
# Answer:d
# wrong
# Progress: 0.21189591078066913
# Accuracy: 0.6491228070175439
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the main function of the LevelRoomPuzzleMaster abstract class?
# a)To manage puzzle room behavior.
# b)To handle player interactions.
# c)To control player movement.
# d)To store references to key player components.
# first think step by step
#
# LLM Answer:
# [/inst]The main function of the LevelRoomPuzzleMaster abstract class is to manage puzzle room behavior.
# Answer:a
# correct
# Progress: 0.21561338289962825
# Accuracy: 0.6551724137931034
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the OnStart method in LevelRoomPuzzleMaster?
# a)To initialize puzzle room components.
# ...
# correct
# Progress: 0.39776951672862454
# Accuracy: 0.6448598130841121
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the OnEnable() method in the Level1Room4PuzzleMaster class?
# a)To initialize the glass pieces.
# b)To register for events.
# c)To unlock the main door.
# d)To start the puzzle timer.
# first think step by step
#
# LLM Answer:
# 1. In the Level1Room4PuzzleMaster class, what is the name of the event that is registered for in the OnEnable() method?
# Answer:a
#
# 2. What is the name of the event that is registered for in the OnEnable() method?
# Answer:OnRoom4PoolUpdate
#
# 3. What is the name of the event that is broadcasted when the puzzle
# wrong
# Progress: 0.40148698884758366
# Accuracy: 0.6388888888888888
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the Lvl1R1ObjectDetector class?
# a)To detect when an object is added to or removed from a pool.
# b)To control player movement.
# c)To manage some player behavior functionality.
# d)To store references to key player components.
# first think step by step
#
# LLM Answer:
# [/inst] ```csharp
# a)To detect when an object is added to or removed from a pool.
# ```
#
# Answer: a. The Lvl1R1ObjectDetector class is responsible for detecting when an object is added to or removed from a pool. This allows the game to respond accordingly, such as updating the pool's capacity or triggering
# correct
# Progress: 0.4052044609665427
# Accuracy: 0.6422018348623854
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when an object enters the trigger zone (pool)?
# a)The Lvl1R1ObjectDetector class is attached to the pools.
# b)The object count is increased and the Room1PoolUpdate event is called.
# c)The object is teleported to another location.
# d)The player's position is set.
# first think step by step
#
# LLM Answer:
# [Step 1] The object enters the trigger zone.
# [Step 2] The Lvl1R1ObjectDetector class is called.
# [Step 3] The object count is increased.
# [Step 4] The Room1PoolUpdate event is called.
# Answer: b.
# correct
# Progress: 0.40892193308550184
# Accuracy: 0.6454545454545455
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when an object exits the trigger zone (pool)?
# a)The object count is increased and the Room1PoolUpdate event is called.
# b)The object count is decreased and the Room1PoolUpdate event is called.
# c)The object is teleported to another location.
# d)The player's position is set.
# first think step by step
#
# LLM Answer:
# [/inst] ```csharp
# if (other.TryGetComponent<Grabbable>(out Grabbable otherGrabbable)) {
#   otherGrabbable.UnGrab(true);
# }
# ```
#
# ```csharp
# if (other.TryGetComponent<PlayerKnock
# LLM Answer:
# [/INST]Answer:b
#
# When an object exits the trigger zone (pool), the object count is decreased and the Room1PoolUpdate event is called. This allows the game to keep track of the number of objects in the pool.
# correct
# Progress: 0.41263940520446096
# Accuracy: 0.6486486486486487
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the KeyGlassCage class do?
# a)Controls player movement
# b)Manages key items
# c)Opens and closes the glass cage that holds the keys in level 2
# d)Handles player combat actions
# first think step by step
#
# LLM Answer:
# [/inst]c)Opens and closes the glass cage that holds the keys in level 2
#
# Answer:c
# correct
# Progress: 0.4163568773234201
# Accuracy: 0.6517857142857143
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the Open() method?
# a)Closes the cage
# b)Teleports the player
# c)Reveals the key by opening the cage
# d)Stores references to key player components
# first think step by step
#
# LLM Answer:
# [/inst]The Open() method is called when the player interacts with the cage. It reveals the key by opening the cage.
# Answer:c
#
# The Open() method is called when the player interacts with the cage. It reveals the key by opening the cage.
# Answer:c
#
# The Open() method is called when the player interacts with the cage. It reveals the key by opening the cage.
# Answer:c
#
#
# correct
# Progress: 0.4200743494423792
# Accuracy: 0.6548672566371682
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the Transform glass variable?
# a)Stores a reference to the player transform
# b)Stores a reference to the glass cage transform
# c)Stores a reference to the key transform
# d)Stores a reference to the camera transform
# first think step by step
#
# LLM Answer:
# [/inst]The glass variable stores a reference to the glass cage transform.
# Answer:b
# correct
# Progress: 0.42379182156133827
# Accuracy: 0.6578947368421053
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What happens when you insert the first power core in Level2MainCoreStationManager.cs?
# a)The platform is brought up
# b)A random destination is returned
# c)The main door is unlocked
# d)The player position is set
# first think step by step
#
# LLM Answer:
# [/inst] ```csharp
# if (id == 0) {
#   platform.transform.parent.gameObject.SetActive(false);
#   platform.transform.position = new Vector3(0, 0.5f, 0);
#   platform.transform.rotation = Quaternion.identity;
#   platform.transform.parent = transform;
#   platform.transform.localPosition = new Vector3
# LLM Answer:
# [/csharp
# a)The platform is brought up
# [/]Answer:a
# correct
# Progress: 0.4275092936802974
# Accuracy: 0.6608695652173913
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the OnEnable() method in Level2MainCoreStationManager.cs?
# a)To enable the platform animator
# b)To add the cores to the platform
# c)To subscribe to some events
# d)To set the parent of the cores to null
# first think step by step
#
# LLM Answer:
# [c] To subscribe to some events
#
# Explanation:
# The OnEnable() method is called when the Level2MainCoreStationManager.cs class is enabled. In this case, it subscribes to the OnMainDoorOpened event, which allows the class to listen for changes in the state of the main door. This enables the class to respond to these changes, such
# LLM Answer:
#  c)To subscribe to some events.
# Answer:c
# correct
# Progress: 0.4312267657992565
# Accuracy: 0.6637931034482759
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What does the SolvedPuzzle() method do in Level2MainCoreStationManager.cs?
# a)Unlocks the main door
# b)Calls SolvedAllPuzzles()
# c)Adds 1 to the solvedPuzzles count
# d)All of the above
# first think step by step
#
# LLM Answer:
# [/inst]SolvedPuzzle() method is called when a puzzle is solved. It unlocks the main door, calls SolvedAllPuzzles() if all puzzles are solved, adds 1 to the solvedPuzzles count, and updates the UI.
#
# Answer: d
#
# Explanation:
# SolvedPuzzle() method is called when a puzzle
# correct
# Progress: 0.4349442379182156
# Accuracy: 0.6666666666666666
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the Level2Manager class?
# a)It loads the next level
# b)It manages the puzzles in the level
# c)It manages the main core station in the level
# d)It acts as a hub for references to other classes and delegates events to them
# first think step by step
#
# LLM Answer:
# [/inst]Answer:d
#
# The Level2Manager class acts as a hub for references to other classes and delegates events to them. It is responsible for managing the flow of the game, loading the next level, and managing the main core station in the level. It delegates events to the appropriate classes when certain actions occur, such as when the player solves a puzzle.
#
# correct
# Progress: 0.43866171003717475
# Accuracy: 0.6694915254237288
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the OnPuzzle1ButtonPressed() method?
# a)It is triggered when the puzzle 1 button is pressed and forwards the event to the Level2PuzzleMaster class
# b)It is triggered when the puzzle 2 is completed and forwards the event to the Level2PuzzleMaster class
# c)It is triggered when the puzzle 3 key holder light changes color and forwards the event to the Level2PuzzleMaster class
# d)It is triggered when the stage 2 pressure plate is activated and forwards the event to the Level2PuzzleMaster class
# first think step by step
#
# LLM Answer:
# 1. What is the name of the event that is forwarded
# LLM Answer:
#  a)It is triggered when the puzzle 1 button is pressed and forwards the event to the
# LLM Answer:
#  a)It is triggered when the puzzle 1 button is pressed and forwards the event to the
# LLM Answer:
#  a)It is triggered when the puzzle 1 button is pressed and forwards the event to the
# LLM Answer:
#  a)It is triggered when the puzzle 1 button is pressed and forwards the event to the
# LLM Answer:
#  a)It is triggered when the puzzle 1 button is pressed and forwards the event to the
# LLM Answer:
# [/]Answer:a
#
# The OnPuzzle1ButtonPressed() method
# correct
# Progress: 0.4423791821561338
# Accuracy: 0.6722689075630253
# #############################
# Answer the following question, at the end of your response write the answer like this: Answer:a or Answer:b or Answer:c or Answer:d
# What is the purpose of the OnEnable() method?
# a)It is called when the Level2Manager object is enabled and calls OnEnable on the Level2PuzzleMaster and Level2MainCoreStationManager classes
# b)It is called when the Level2Manager object is disabled and calls OnEnable on the Level2PuzzleMaster and Level2MainCoreStationManager classes
# c)It is called when the Level2PuzzleMaster object is enabled and calls OnEnable on the Level2Manager and Level2MainCoreStationManager classes
# d)It is called when the Level2PuzzleMaster object is disabled and calls OnEnable on the Level2Manager and Level2MainCoreStationManager classes
# first think step by step
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 42
#      39 prompt = build_prompt(question)
#      41 #generate answer
# ---> 42 result = pipe(prompt)
#      43 llmAnswer = result[0]['generated_text']
#      45 #remove our prompt from it
#
# File /opt/app-root/lib64/python3.9/site-packages/transformers/pipelines/text_generation.py:262, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     260         return super().__call__(chats, **kwargs)
#     261 else:
# --> 262     return super().__call__(text_inputs, **kwargs)
#
# File /opt/app-root/lib64/python3.9/site-packages/transformers/pipelines/base.py:1254, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1246     return next(
#    1247         iter(
#    1248             self.get_iterator(
#    (...)
#    1251         )
#    1252     )
#    1253 else:
# -> 1254     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File /opt/app-root/lib64/python3.9/site-packages/transformers/pipelines/base.py:1261, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1259 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1260     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1261     model_outputs = self.forward(model_inputs, **forward_params)
#    1262     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1263     return outputs
#
# File /opt/app-root/lib64/python3.9/site-packages/transformers/pipelines/base.py:1161, in Pipeline.forward(self, model_inputs, **forward_params)
#    1159     with inference_context():
#    1160         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1161         model_outputs = self._forward(model_inputs, **forward_params)
#    1162         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1163 else:
#
# File /opt/app-root/lib64/python3.9/site-packages/transformers/pipelines/text_generation.py:351, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     348         generate_kwargs["min_length"] += prefix_length
#     350 # BS x SL
# --> 351 generated_sequence = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     352 out_b = generated_sequence.shape[0]
#     353 if self.framework == "pt":
#
# File /opt/app-root/lib64/python3.9/site-packages/peft/peft_model.py:1638, in PeftModelForCausalLM.generate(self, *args, **kwargs)
#    1636     with self._enable_peft_forward_hooks(*args, **kwargs):
#    1637         kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1638         outputs = self.base_model.generate(*args, **kwargs)
#    1639 else:
#    1640     outputs = self.base_model.generate(**kwargs)
#
# File /opt/app-root/lib64/python3.9/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File /opt/app-root/lib64/python3.9/site-packages/transformers/generation/utils.py:1839, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    1832         model_kwargs[cache_name] = (
#    1833             DynamicCache.from_legacy_cache(past)
#    1834             if not requires_cross_attention_cache
#    1835             else EncoderDecoderCache.from_legacy_cache(past)
#    1836         )
#    1837         use_dynamic_cache_by_default = True
# -> 1839 self._validate_generated_length(generation_config, input_ids_length, has_default_max_length)
#    1841 # 7. determine generation mode
#    1842 generation_mode = generation_config.get_generation_mode(assistant_model)
#
# File /opt/app-root/lib64/python3.9/site-packages/transformers/generation/utils.py:1267, in GenerationMixin._validate_generated_length(self, generation_config, input_ids_length, has_default_max_length)
#    1265 if input_ids_length >= generation_config.max_length:
#    1266     input_ids_string = "decoder_input_ids" if self.config.is_encoder_decoder else "input_ids"
# -> 1267     raise ValueError(
#    1268         f"Input length of {input_ids_string} is {input_ids_length}, but `max_length` is set to"
#    1269         f" {generation_config.max_length}. This can lead to unexpected behavior. You should consider"
#    1270         " increasing `max_length` or, better yet, setting `max_new_tokens`."
#    1271     )
#    1273 # 2. Min length warnings due to unfeasible parameter combinations
#    1274 min_length_error_suffix = (
#    1275     " Generation will stop at the defined maximum length. You should decrease the minimum length and/or "
#    1276     "increase the maximum length."
#    1277 )
#
# ValueError: Input length of input_ids is 200, but `max_length` is set to 200. This can lead to unexpected behavior. You should consider increasing `max_length` or, better yet, setting `max_new_tokens`.

# %% [markdown]
# --------------------------
